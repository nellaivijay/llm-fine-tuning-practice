# %% [markdown]
# # Chapter 3: The Fine-Tuner's Workshop
#
# This notebook covers environment setup for fine-tuning.

# %% [markdown]
# ## GPU Verification

# %%
import torch

print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU count: {torch.cuda.device_count()}")
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")

# %% [markdown]
# ## Install Dependencies

# %%
# Install required packages (run in terminal if needed)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers datasets peft bitsandbytes accelerate

print("Dependencies should be installed via requirements.txt")

# %% [markdown]
# ## Test Model Loading

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load a small model for testing
model_name = "gpt2"  # Small model for testing

print("Loading model...")
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

print(f"Model loaded: {model_name}")
print(f"Model parameters: {sum(p.numel() for p in model.parameters()) / 1e6:.2f}M")

# %% [markdown]
# ## Test PEFT Configuration

# %%
from peft import LoraConfig, get_peft_model

# Configure LoRA
lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["c_attn"],  # GPT-2 specific
    lora_dropout=0.05,
    task_type="CAUSAL_LM"
)

# Apply LoRA
model = get_peft_model(model, lora_config)

model.print_trainable_parameters()

# %% [markdown]
# ## Memory Test

# %%
if torch.cuda.is_available():
    # Move model to GPU
    model = model.to('cuda')
    
    # Check memory
    print(f"Allocated: {torch.cuda.memory_allocated(0) / 1024**3:.2f} GB")
    print(f"Reserved: {torch.cuda.memory_reserved(0) / 1024**3:.2f} GB")

# %% [markdown]
# ## Key Takeaways
#
# 1. Verify GPU access before training
# 2. Install correct CUDA version
# 3. Test model loading and PEFT configuration
# 4. Check GPU memory availability
# 5. Environment setup is crucial for success
